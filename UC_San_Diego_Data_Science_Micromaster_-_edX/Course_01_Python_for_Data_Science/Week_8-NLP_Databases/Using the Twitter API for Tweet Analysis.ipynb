# %% [markdown]
# # Twitter data
#
# ## Copyright and Licensing
#
# You are free to use or adapt this notebook for any purpose you'd like. However, please respect the [Simplified BSD License](https://github.com/ptwobrussell/Mining-the-Social-Web-2nd-Edition/blob/master/LICENSE.txt) that governs its use.

# %% [markdown]
# # Twitter API Access
#
# Twitter implements OAuth 1.0A as its standard authentication mechanism, and in order to use it to make requests to Twitter's API, you'll need to go to https://dev.twitter.com/apps and create a sample application.
#
# Choose any name for your application, write a description and use `http://google.com` for the website.
#
# Under **Key and Access Tokens**, there are four primary identifiers you'll need to note for an OAuth 1.0A workflow:
# * consumer key,
# * consumer secret,
# * access token, and
# * access token secret (Click on Create Access Token to create those).
#
# Note that you will need an ordinary Twitter account in order to login, create an app, and get these credentials.

# %% [markdown]
# The first time you execute the notebook, add all credentials so that you can save them in the `pkl` file, then you can remove the secret keys from the notebook because they will just be loaded from the `pkl` file.
#
# The `pkl` file contains sensitive information that can be used to take control of your twitter acccount, **do not share it**.

# %%
import pickle
import os

# %%
if not os.path.exists('secret_twitter_credentials.pkl'):
    Twitter={}
    Twitter['Consumer Key'] = 'PJltWkpqGafHgwxHhEWOa3Yd6'
    Twitter['Consumer Secret'] = 'M8XjkaGHrQr0AP7iiXUf5Eq74lO5CNdRa0C86JOePlx84qevE9'
    Twitter['Access Token'] = '4569071-70RMr6SFOUqrVz76FQGtzd3K0tlXdbL5MJq74eWsId'
    Twitter['Access Token Secret'] = 'VwhthQYTSGxupS0ooEkL5T1oeBqYqPwO1UVMaBrmMi1YD'
    with open('secret_twitter_credentials.pkl','wb') as f:
        pickle.dump(Twitter, f)
else:
    Twitter=pickle.load(open('secret_twitter_credentials.pkl','rb'))

# %% [markdown]
# Install the `twitter` package to interface with the Twitter API

# %%
# !pip install twitter
# Out:
# Collecting twitter
#   Downloading twitter-1.17.1-py2.py3-none-any.whl (55kB)
# Installing collected packages: twitter
# Successfully installed twitter-1.17.1

# %% [markdown]
# ## Example 1. Authorizing an application to access Twitter account data

# %%
import twitter

auth = twitter.oauth.OAuth(Twitter['Access Token'],
                           Twitter['Access Token Secret'],
                           Twitter['Consumer Key'],
                           Twitter['Consumer Secret'])

twitter_api = twitter.Twitter(auth=auth)

# Nothing to see by displaying twitter_api except that it's now a
# defined variable

print(twitter_api)
# Out:
# <twitter.api.Twitter object at 0x000001DED5DE5208>

# %% [markdown]
# ## Example 2. Retrieving trends

# %% [markdown]
# Twitter identifies locations using the Yahoo! Where On Earth ID.
#
# The Yahoo! Where On Earth ID for the entire world is 1.
# See https://dev.twitter.com/docs/api/1.1/get/trends/place and
# http://developer.yahoo.com/geo/geoplanet/
#
# look at the BOSS placefinder here: https://developer.yahoo.com/boss/placefinder/

# %%
WORLD_WOE_ID = 1
#US_WOE_ID = 23424977
COL_WOE_ID = 23424787

# %% [markdown]
# Look for the WOEID for [san-diego](http://woeid.rosselliot.co.nz/lookup/san%20diego%20%20ca)
#
# You can change it to another location.

# %%
LOCAL_WOE_ID=368148 #Bogotá, CO

# Prefix ID with the underscore for query string parameterization.
# Without the underscore, the twitter package appends the ID value
# to the URL itself as a special case keyword argument.

world_trends = twitter_api.trends.place(_id=WORLD_WOE_ID)
col_trends = twitter_api.trends.place(_id=COL_WOE_ID)
local_trends = twitter_api.trends.place(_id=LOCAL_WOE_ID)

# %%
world_trends[:2]
# Out:
# [{'as_of': '2017-08-27T12:20:13Z',
#   'created_at': '2017-08-27T12:13:37Z',
#   'locations': [{'name': 'Worldwide', 'woeid': 1}],
#   'trends': [{'name': '#BelgianGP',
#     'promoted_content': None,
#     'query': '%23BelgianGP',
#     'tweet_volume': 61555,
#     'url': 'http://twitter.com/search?q=%23BelgianGP'},
#    {'name': '#ماذا_قدموا_مشايخ_الشمل_للمواطن',
#     'promoted_content': None,
#     'query': '%23%D9%85%D8%A7%D8%B0%D8%A7_%D9%82%D8%AF%D9%85%D9%88%D8%A7_%D9%85%D8%B4%D8%A7%D9%8A%D8%AE_%D8%A7%D9%84%D8%B4%D9%85%D9%84_%D9%84%D9%84%D9%85%D9%88%D8%A7%D8%B7%D9%86',
#     'tweet_volume': 22318,
#     'url': 'http://twitter.com/search?q=%23%D9%85%D8%A7%D8%B0%D8%A7_%D9%82%D8%AF%D9%85%D9%88%D8%A7_%D9%85%D8%B4%D8%A7%D9%8A%D8%AE_%D8%A7%D9%84%D8%B4%D9%85%D9%84_%D9%84%D9%84%D9%85%D9%88%D8%A7%D8%B7%D9%86'},
#    {'name': '#FelizDomingo',
#     'promoted_content': None,
#     'query': '%23FelizDomingo',
#     'tweet_volume': 14236,
#     'url': 'http://twitter.com/search?q=%23FelizDomingo'},
#    {'name': 'Tobe Hooper',
#     'promoted_content': None,
#     'query': '%22Tobe+Hooper%22',
#     'tweet_volume': 29164,
#     'url': 'http://twitter.com/search?q=%22Tobe+Hooper%22'},
#    {'name': '#تقول_لمين_اتفوو',
#     'promoted_content': None,
#     'query': '%23%D8%AA%D9%82%D9%88%D9%84_%D9%84%D9%85%D9%8A%D9%86_%D8%A7%D8%AA%D9%81%D9%88%D9%88',
#     'tweet_volume': 60783,
#     'url': 'http://twitter.com/search?q=%23%D8%AA%D9%82%D9%88%D9%84_%D9%84%D9%85%D9%8A%D9%86_%D8%A7%D8%AA%D9%81%D9%88%D9%88'},
#    {'name': '#وش_تتمني_عيديتك',
#     'promoted_content': None,
#     'query': '%23%D9%88%D8%B4_%D8%AA%D8%AA%D9%85%D9%86%D9%8A_%D8%B9%D9%8A%D8%AF%D9%8A%D8%AA%D9%83',
#     'tweet_volume': 86168,
#     'url': 'http://twitter.com/search?q=%23%D9%88%D8%B4_%D8%AA%D8%AA%D9%85%D9%86%D9%8A_%D8%B9%D9%8A%D8%AF%D9%8A%D8%AA%D9%83'},
#    {'name': 'withB',
#     'promoted_content': None,
#     'query': 'withB',
#     'tweet_volume': 30312,
#     'url': 'http://twitter.com/search?q=withB'},
#    {'name': 'サライ',
#     'promoted_content': None,
#     'query': '%E3%82%B5%E3%83%A9%E3%82%A4',
#     'tweet_volume': 18633,
#     'url': 'http://twitter.com/search?q=%E3%82%B5%E3%83%A9%E3%82%A4'},
#    {'name': 'Mick Schumacher',
#     'promoted_content': None,
#     'query': '%22Mick+Schumacher%22',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%22Mick+Schumacher%22'},
#    {'name': 'ブルゾンちえみ',
#     'promoted_content': None,
#     'query': '%E3%83%96%E3%83%AB%E3%82%BE%E3%83%B3%E3%81%A1%E3%81%88%E3%81%BF',
#     'tweet_volume': 189758,
#     'url': 'http://twitter.com/search?q=%E3%83%96%E3%83%AB%E3%82%BE%E3%83%B3%E3%81%A1%E3%81%88%E3%81%BF'},
#    {'name': 'One Love',
#     'promoted_content': None,
#     'query': '%22One+Love%22',
#     'tweet_volume': 20049,
#     'url': 'http://twitter.com/search?q=%22One+Love%22'},
#    {'name': 'Mignolet',
#     'promoted_content': None,
#     'query': 'Mignolet',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=Mignolet'},
#    {'name': '鉄腕DASH',
#     'promoted_content': None,
#     'query': '%E9%89%84%E8%85%95DASH',
#     'tweet_volume': 15830,
#     'url': 'http://twitter.com/search?q=%E9%89%84%E8%85%95DASH'},
#    {'name': 'Enric González',
#     'promoted_content': None,
#     'query': '%22Enric+Gonz%C3%A1lez%22',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%22Enric+Gonz%C3%A1lez%22'},
#    {'name': 'Karius',
#     'promoted_content': None,
#     'query': 'Karius',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=Karius'},
#    {'name': 'La Diada del Terror',
#     'promoted_content': None,
#     'query': '%22La+Diada+del+Terror%22',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%22La+Diada+del+Terror%22'},
#    {'name': 'Mutlu Pazarlar',
#     'promoted_content': None,
#     'query': '%22Mutlu+Pazarlar%22',
#     'tweet_volume': 19790,
#     'url': 'http://twitter.com/search?q=%22Mutlu+Pazarlar%22'},
#    {'name': '3rd ODI',
#     'promoted_content': None,
#     'query': '%223rd+ODI%22',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%223rd+ODI%22'},
#    {'name': '龍雲丸',
#     'promoted_content': None,
#     'query': '%E9%BE%8D%E9%9B%B2%E4%B8%B8',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%E9%BE%8D%E9%9B%B2%E4%B8%B8'},
#    {'name': '#feywil',
#     'promoted_content': None,
#     'query': '%23feywil',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23feywil'},
#    {'name': '#houstonflood',
#     'promoted_content': None,
#     'query': '%23houstonflood',
#     'tweet_volume': 19052,
#     'url': 'http://twitter.com/search?q=%23houstonflood'},
#    {'name': '#DeshBachao',
#     'promoted_content': None,
#     'query': '%23DeshBachao',
#     'tweet_volume': 48758,
#     'url': 'http://twitter.com/search?q=%23DeshBachao'},
#    {'name': '#BANvAUS',
#     'promoted_content': None,
#     'query': '%23BANvAUS',
#     'tweet_volume': 11462,
#     'url': 'http://twitter.com/search?q=%23BANvAUS'},
#    {'name': '#CHEEVE',
#     'promoted_content': None,
#     'query': '%23CHEEVE',
#     'tweet_volume': 12995,
#     'url': 'http://twitter.com/search?q=%23CHEEVE'},
#    {'name': '#يلا_نردد_استغفرالله',
#     'promoted_content': None,
#     'query': '%23%D9%8A%D9%84%D8%A7_%D9%86%D8%B1%D8%AF%D8%AF_%D8%A7%D8%B3%D8%AA%D8%BA%D9%81%D8%B1%D8%A7%D9%84%D9%84%D9%87',
#     'tweet_volume': 55007,
#     'url': 'http://twitter.com/search?q=%23%D9%8A%D9%84%D8%A7_%D9%86%D8%B1%D8%AF%D8%AF_%D8%A7%D8%B3%D8%AA%D8%BA%D9%81%D8%B1%D8%A7%D9%84%D9%84%D9%87'},
#    {'name': '#SundayMorning',
#     'promoted_content': None,
#     'query': '%23SundayMorning',
#     'tweet_volume': 15969,
#     'url': 'http://twitter.com/search?q=%23SundayMorning'},
#    {'name': '#NamimissKoYung',
#     'promoted_content': None,
#     'query': '%23NamimissKoYung',
#     'tweet_volume': 10329,
#     'url': 'http://twitter.com/search?q=%23NamimissKoYung'},
#    {'name': '#FenerinMaçıVar',
#     'promoted_content': None,
#     'query': '%23FenerinMa%C3%A7%C4%B1Var',
#     'tweet_volume': 12127,
#     'url': 'http://twitter.com/search?q=%23FenerinMa%C3%A7%C4%B1Var'},
#    {'name': '#AFLEaglesCrows',
#     'promoted_content': None,
#     'query': '%23AFLEaglesCrows',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23AFLEaglesCrows'},
#    {'name': '#Cite4CoisasQueVcAma',
#     'promoted_content': None,
#     'query': '%23Cite4CoisasQueVcAma',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23Cite4CoisasQueVcAma'},
#    {'name': '#DomingoDetremuraSDV',
#     'promoted_content': None,
#     'query': '%23DomingoDetremuraSDV',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23DomingoDetremuraSDV'},
#    {'name': '#vvvaja',
#     'promoted_content': None,
#     'query': '%23vvvaja',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23vvvaja'},
#    {'name': '#F1xFOX',
#     'promoted_content': None,
#     'query': '%23F1xFOX',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23F1xFOX'},
#    {'name': '#خميس_مشيط',
#     'promoted_content': None,
#     'query': '%23%D8%AE%D9%85%D9%8A%D8%B3_%D9%85%D8%B4%D9%8A%D8%B7',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23%D8%AE%D9%85%D9%8A%D8%B3_%D9%85%D8%B4%D9%8A%D8%B7'},
#    {'name': '#JLMMarseille',
#     'promoted_content': None,
#     'query': '%23JLMMarseille',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23JLMMarseille'},
#    {'name': '#DejadHablarAGabriel',
#     'promoted_content': None,
#     'query': '%23DejadHablarAGabriel',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23DejadHablarAGabriel'},
#    {'name': '#NottingHillCarnival',
#     'promoted_content': None,
#     'query': '%23NottingHillCarnival',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23NottingHillCarnival'},
#    {'name': '#we_are_one',
#     'promoted_content': None,
#     'query': '%23we_are_one',
#     'tweet_volume': 10761,
#     'url': 'http://twitter.com/search?q=%23we_are_one'},
#    {'name': '#HTCMania',
#     'promoted_content': None,
#     'query': '%23HTCMania',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23HTCMania'},
#    {'name': '#27Ago',
#     'promoted_content': None,
#     'query': '%2327Ago',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%2327Ago'},
#    {'name': '#buitenhof',
#     'promoted_content': None,
#     'query': '%23buitenhof',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23buitenhof'},
#    {'name': '#BOCSGD',
#     'promoted_content': None,
#     'query': '%23BOCSGD',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23BOCSGD'},
#    {'name': '#MannKiBaat',
#     'promoted_content': None,
#     'query': '%23MannKiBaat',
#     'tweet_volume': 52089,
#     'url': 'http://twitter.com/search?q=%23MannKiBaat'},
#    {'name': '#masterchefthailand',
#     'promoted_content': None,
#     'query': '%23masterchefthailand',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23masterchefthailand'},
#    {'name': '#dopa',
#     'promoted_content': None,
#     'query': '%23dopa',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23dopa'},
#    {'name': '#バリバラ',
#     'promoted_content': None,
#     'query': '%23%E3%83%90%E3%83%AA%E3%83%90%E3%83%A9',
#     'tweet_volume': 14193,
#     'url': 'http://twitter.com/search?q=%23%E3%83%90%E3%83%AA%E3%83%90%E3%83%A9'},
#    {'name': '#ShakespeareSunday',
#     'promoted_content': None,
#     'query': '%23ShakespeareSunday',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23ShakespeareSunday'},
#    {'name': '#رساله_بنت_يتيمه_تعور_القلب',
#     'promoted_content': None,
#     'query': '%23%D8%B1%D8%B3%D8%A7%D9%84%D9%87_%D8%A8%D9%86%D8%AA_%D9%8A%D8%AA%D9%8A%D9%85%D9%87_%D8%AA%D8%B9%D9%88%D8%B1_%D8%A7%D9%84%D9%82%D9%84%D8%A8',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23%D8%B1%D8%B3%D8%A7%D9%84%D9%87_%D8%A8%D9%86%D8%AA_%D9%8A%D8%AA%D9%8A%D9%85%D9%87_%D8%AA%D8%B9%D9%88%D8%B1_%D8%A7%D9%84%D9%82%D9%84%D8%A8'},
#    {'name': '#muzafferizgu',
#     'promoted_content': None,
#     'query': '%23muzafferizgu',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23muzafferizgu'},
#    {'name': '#CursoPoliticoPP',
#     'promoted_content': None,
#     'query': '%23CursoPoliticoPP',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23CursoPoliticoPP'}]}]

# %%
trends=local_trends
print(type(trends))
print(list(trends[0].keys()))
print(trends[0]['trends'])
# Out:
# <class 'twitter.api.TwitterListResponse'>
# ['trends', 'as_of', 'created_at', 'locations']
# [{'name': '#McGregor', 'url': 'http://twitter.com/search?q=%23McGregor', 'promoted_content': None, 'query': '%23McGregor', 'tweet_volume': 475711}, {'name': '#PeleaDelSiglo', 'url': 'http://twitter.com/search?q=%23PeleaDelSiglo', 'promoted_content': None, 'query': '%23PeleaDelSiglo', 'tweet_volume': None}, {'name': 'Manuel', 'url': 'http://twitter.com/search?q=Manuel', 'promoted_content': None, 'query': 'Manuel', 'tweet_volume': 1209997}, {'name': 'Uribe', 'url': 'http://twitter.com/search?q=Uribe', 'promoted_content': None, 'query': 'Uribe', 'tweet_volume': 16024}, {'name': '#FelizDomingo', 'url': 'http://twitter.com/search?q=%23FelizDomingo', 'promoted_content': None, 'query': '%23FelizDomingo', 'tweet_volume': 14236}, {'name': '#F1xFOX', 'url': 'http://twitter.com/search?q=%23F1xFOX', 'promoted_content': None, 'query': '%23F1xFOX', 'tweet_volume': None}, {'name': '#ICFES', 'url': 'http://twitter.com/search?q=%23ICFES', 'promoted_content': None, 'query': '%23ICFES', 'tweet_volume': None}, {'name': 'Primera Emisión', 'url': 'http://twitter.com/search?q=%22Primera+Emisi%C3%B3n%22', 'promoted_content': None, 'query': '%22Primera+Emisi%C3%B3n%22', 'tweet_volume': None}, {'name': 'Egan Bernal', 'url': 'http://twitter.com/search?q=%22Egan+Bernal%22', 'promoted_content': None, 'query': '%22Egan+Bernal%22', 'tweet_volume': None}, {'name': 'Quintero', 'url': 'http://twitter.com/search?q=Quintero', 'promoted_content': None, 'query': 'Quintero', 'tweet_volume': None}, {'name': 'Cuadrado', 'url': 'http://twitter.com/search?q=Cuadrado', 'promoted_content': None, 'query': 'Cuadrado', 'tweet_volume': 21739}, {'name': 'Chará', 'url': 'http://twitter.com/search?q=Char%C3%A1', 'promoted_content': None, 'query': 'Char%C3%A1', 'tweet_volume': 13223}, {'name': 'Death Note', 'url': 'http://twitter.com/search?q=%22Death+Note%22', 'promoted_content': None, 'query': '%22Death+Note%22', 'tweet_volume': 206192}, {'name': 'Texas', 'url': 'http://twitter.com/search?q=Texas', 'promoted_content': None, 'query': 'Texas', 'tweet_volume': 679417}, {'name': 'Once Caldas', 'url': 'http://twitter.com/search?q=%22Once+Caldas%22', 'promoted_content': None, 'query': '%22Once+Caldas%22', 'tweet_volume': None}, {'name': 'Conor', 'url': 'http://twitter.com/search?q=Conor', 'promoted_content': None, 'query': 'Conor', 'tweet_volume': 1219421}, {'name': 'Ovelar', 'url': 'http://twitter.com/search?q=Ovelar', 'promoted_content': None, 'query': 'Ovelar', 'tweet_volume': None}, {'name': 'Venezuela y Brasil', 'url': 'http://twitter.com/search?q=%22Venezuela+y+Brasil%22', 'promoted_content': None, 'query': '%22Venezuela+y+Brasil%22', 'tweet_volume': None}, {'name': 'Juventus', 'url': 'http://twitter.com/search?q=Juventus', 'promoted_content': None, 'query': 'Juventus', 'tweet_volume': 43935}, {'name': 'Tigres', 'url': 'http://twitter.com/search?q=Tigres', 'promoted_content': None, 'query': 'Tigres', 'tweet_volume': 13899}, {'name': 'Piedecuesta', 'url': 'http://twitter.com/search?q=Piedecuesta', 'promoted_content': None, 'query': 'Piedecuesta', 'tweet_volume': None}, {'name': 'Demi Lovato', 'url': 'http://twitter.com/search?q=%22Demi+Lovato%22', 'promoted_content': None, 'query': '%22Demi+Lovato%22', 'tweet_volume': 161607}, {'name': 'Chuck Norris', 'url': 'http://twitter.com/search?q=%22Chuck+Norris%22', 'promoted_content': None, 'query': '%22Chuck+Norris%22', 'tweet_volume': None}, {'name': '#MargaritaOrtega', 'url': 'http://twitter.com/search?q=%23MargaritaOrtega', 'promoted_content': None, 'query': '%23MargaritaOrtega', 'tweet_volume': None}, {'name': '#FelizSabado', 'url': 'http://twitter.com/search?q=%23FelizSabado', 'promoted_content': None, 'query': '%23FelizSabado', 'tweet_volume': 35580}, {'name': '#PremiumXDIRECTV', 'url': 'http://twitter.com/search?q=%23PremiumXDIRECTV', 'promoted_content': None, 'query': '%23PremiumXDIRECTV', 'tweet_volume': None}, {'name': '#BatallaDeLosGallos', 'url': 'http://twitter.com/search?q=%23BatallaDeLosGallos', 'promoted_content': None ...

# %% [markdown]
# ## Example 3. Displaying API responses as pretty-printed JSON

# %%
import json

print((json.dumps(col_trends[:2], indent=2)))
# Out:
# [
#   {
#     "trends": [
#       {
#         "name": "#FelizDomingo",
#         "url": "http://twitter.com/search?q=%23FelizDomingo",
#         "promoted_content": null,
#         "query": "%23FelizDomingo",
#         "tweet_volume": 14236
#       },
#       {
#         "name": "#F1xFOX",
#         "url": "http://twitter.com/search?q=%23F1xFOX",
#         "promoted_content": null,
#         "query": "%23F1xFOX",
#         "tweet_volume": null
#       },
#       {
#         "name": "#ICFES",
#         "url": "http://twitter.com/search?q=%23ICFES",
#         "promoted_content": null,
#         "query": "%23ICFES",
#         "tweet_volume": null
#       },
#       {
#         "name": "Primera Emisi\u00f3n",
#         "url": "http://twitter.com/search?q=%22Primera+Emisi%C3%B3n%22",
#         "promoted_content": null,
#         "query": "%22Primera+Emisi%C3%B3n%22",
#         "tweet_volume": null
#       },
#       {
#         "name": "#MargaritaOrtega",
#         "url": "http://twitter.com/search?q=%23MargaritaOrtega",
#         "promoted_content": null,
#         "query": "%23MargaritaOrtega",
#         "tweet_volume": null
#       },
#       {
#         "name": "#McGregor",
#         "url": "http://twitter.com/search?q=%23McGregor",
#         "promoted_content": null,
#         "query": "%23McGregor",
#         "tweet_volume": 475711
#       },
#       {
#         "name": "Manuel",
#         "url": "http://twitter.com/search?q=Manuel",
#         "promoted_content": null,
#         "query": "Manuel",
#         "tweet_volume": 1209997
#       },
#       {
#         "name": "Egan Bernal",
#         "url": "http://twitter.com/search?q=%22Egan+Bernal%22",
#         "promoted_content": null,
#         "query": "%22Egan+Bernal%22",
#         "tweet_volume": null
#       },
#       {
#         "name": "Quintero",
#         "url": "http://twitter.com/search?q=Quintero",
#         "promoted_content": null,
#         "query": "Quintero",
#         "tweet_volume": null
#       },
#       {
#         "name": "Cuadrado",
#         "url": "http://twitter.com/search?q=Cuadrado",
#         "promoted_content": null,
#         "query": "Cuadrado",
#         "tweet_volume": 21739
#       },
#       {
#         "name": "Char\u00e1",
#         "url": "http://twitter.com/search?q=Char%C3%A1",
#         "promoted_content": null,
#         "query": "Char%C3%A1",
#         "tweet_volume": 13223
#       },
#       {
#         "name": "Death Note",
#         "url": "http://twitter.com/search?q=%22Death+Note%22",
#         "promoted_content": null,
#         "query": "%22Death+Note%22",
#         "tweet_volume": 206192
#       },
#       {
#         "name": "Texas",
#         "url": "http://twitter.com/search?q=Texas",
#         "promoted_content": null,
#         "query": "Texas",
#         "tweet_volume": 679417
#       },
#       {
#         "name": "Once Caldas",
#         "url": "http://twitter.com/search?q=%22Once+Caldas%22",
#         "promoted_content": null,
#         "query": "%22Once+Caldas%22",
#         "tweet_volume": null
#       },
#       {
#         "name": "Conor",
#         "url": "http://twitter.com/search?q=Conor",
#         "promoted_content": null,
#         "query": "Conor",
#         "tweet_volume": 1219421
#       },
#       {
#         "name": "Ovelar",
#         "url": "http://twitter.com/search?q=Ovelar",
#         "promoted_content": null,
#         "query": "Ovelar",
#         "tweet_volume": null
#       },
#       {
#         "name": "Venezuela y Brasil",
#         "url": "http://twitter.com/search?q=%22Venezuela+y+Brasil%22",
#         "promoted_content": null,
#         "query": "%22Venezuela+y+Brasil%22",
#         "tweet_volume": null
#       },
#       {
#         "name": "Juventus",
#         "url": "http://twitter.com/search?q=Juventus",
#         "promoted_content": null,
#         "query": "Juventus",
#         "tweet_volume": 43935
#       },
#       {
#         "name": "Tigres",
#         "url": "http://twitter.com/search?q=Tigres",
#         "promoted_content": null,
#         "query": "Tigres",
#         "tweet_volume": 13899
#       },
#       {
#         "name": "Piedecuesta",
#         "url": "http://twitter.com/search?q=Piedecuesta",
#         "promoted_content": null,
#         "query": "Piedecuesta",
#         "tweet_volume": null
#       },
#       {
#         "name": "Demi Lovato",
#         "url": "http://twitter.com/search?q=%22Demi+Lovato%22",
#         "promoted_content": null,
#         "query": "%22Demi+Lovato%22",
#         "tweet_volume": 161607
#       },
#       {
#         "name": "Chuck Norris",
#         "url": "http://twitter.com/search?q=%22Chuck+Norris%22",
#         "promoted_content": null,
#         "query": "%22Chuck+Norris%22",
#         "tweet_volume": null
#       },
#       {
#         "name": "#PeleaDelSiglo",
#         "url": "http://twitter.com/search?q=%23PeleaDelSiglo",
#         "promoted_content": null,
#         "query": "%23PeleaDelSiglo",
#         "tweet_volume": null
#       },
#       {
#         "name": "#FelizSabado",
#         "url": "http://twitter.com/search?q=%23FelizSabado",
#         "promoted_content": null,
#         "query": "%23FelizSabado",
#         "tweet_volume": 35580
#       },
#       {
#         "name": "#PremiumXDIRECTV",
#         "url": "http://twitter.com/search?q=%23PremiumXDIRECTV",
#         "promoted_content": null,
#         "query": "%23PremiumXDIRECTV",
#         "tweet_volume": null
#       },
#       {
#         "name": "#BatallaDeLosGallos",
#         "url": "http://twitter.com/search?q=%23BatallaDeLosGallos",
#         "promoted_content": null,
#         "query": "%23BatallaDeLosGallos",
#         "tweet_volume": null
#       },
#       {
#         "name": "#ForoCDTurismo",
#         "url": "http://twitter.com/search?q=%23ForoCDTurismo",
#         "promoted_content": null,
#         "query": "%23ForoCDTurismo",
#         "tweet_volume": null
#       },
#       {
#         "name": "#RadioReal",
#         "url": "http://twitter.com/search?q=%23RadioReal",
#         "promoted_content": null,
#         "query": "%23RadioReal",
#         "tweet_volume": null
#       },
#       {
#         "name": "#D\u00edaDeLaCrispeta",
#         "url": "http://twitter.com/search?q=%23D%C3%ADaDeLaCrispeta",
#         "promoted_content": null,
#         "query": "%23D%C3%ADaDeLaCrispeta",
#         "tweet_volume": null
#       },
#       {
#         "name": "#PeriodistasAsocajas",
#         "url": "http://twitter.com/search?q=%23PeriodistasAsocajas",
#         "promoted_content": null,
#         "query": "%23PeriodistasAsocajas",
#         "tweet_volume": null
#       }
#     ],
#     "as_of": "2017-08-27T12:20:13Z",
#     "created_at": "2017-08-27T12:13:37Z",
#     "locations": [
#       {
#         "name": "Colombia",
#         "woeid": 23424787
#       }
#     ]
#   }
# ]

# %% [markdown]
# ## Example 4. Computing the intersection of two sets of trends

# %%
trends_set = {}
trends_set['world'] = set([trend['name'] 
                        for trend in world_trends[0]['trends']])

trends_set['col'] = set([trend['name'] 
                     for trend in col_trends[0]['trends']]) 

trends_set['bogota'] = set([trend['name'] 
                     for trend in local_trends[0]['trends']])

# %%
for loc in ['world','col','bogota']:
    print(('-'*10,loc))
    print((','.join(trends_set[loc])))
# Out:
# ('----------', 'world')
# #CursoPoliticoPP,#NottingHillCarnival,#27Ago,#ShakespeareSunday,#وش_تتمني_عيديتك,#DomingoDetremuraSDV,3rd ODI,#DeshBachao,Tobe Hooper,#muzafferizgu,#バリバラ,#buitenhof,#ماذا_قدموا_مشايخ_الشمل_للمواطن,#FelizDomingo,#خميس_مشيط,Mick Schumacher,Enric González,#BANvAUS,#يلا_نردد_استغفرالله,One Love,#JLMMarseille,#feywil,Mignolet,#BelgianGP,#we_are_one,#HTCMania,#masterchefthailand,#dopa,#Cite4CoisasQueVcAma,Karius,#SundayMorning,#DejadHablarAGabriel,龍雲丸,#houstonflood,#F1xFOX,withB,#vvvaja,#MannKiBaat,#تقول_لمين_اتفوو,#FenerinMaçıVar,Mutlu Pazarlar,#رساله_بنت_يتيمه_تعور_القلب,La Diada del Terror,ブルゾンちえみ,鉄腕DASH,#BOCSGD,#CHEEVE,#NamimissKoYung,サライ,#AFLEaglesCrows
# ('----------', 'col')
# #MargaritaOrtega,Quintero,Piedecuesta,#RadioReal,Manuel,Cuadrado,Chará,#ICFES,Ovelar,Juventus,#BatallaDeLosGallos,#FelizDomingo,Conor,#FelizSabado,Once Caldas,Primera Emisión,#PeleaDelSiglo,Chuck Norris,#McGregor,#F1xFOX,Egan Bernal,#DíaDeLaCrispeta,Tigres,#PeriodistasAsocajas,#ForoCDTurismo,Demi Lovato,Venezuela y Brasil,Texas,#PremiumXDIRECTV,Death Note
# ('----------', 'bogota')
# #MargaritaOrtega,Quintero,Piedecuesta,#RadioReal,Manuel,Cuadrado,Chará,#ICFES,Ovelar,Juventus,#BatallaDeLosGallos,#FelizDomingo,Conor,#FelizSabado,Once Caldas,Primera Emisión,#PeleaDelSiglo,Chuck Norris,#McGregor,#F1xFOX,Uribe,Egan Bernal,#DíaDeLaCrispeta,Tigres,#PeriodistasAsocajas,#ForoCDTurismo,Demi Lovato,Venezuela y Brasil,Texas,#PremiumXDIRECTV,Death Note

# %%
print(( '='*10,'intersection of world and colombia'))
print((trends_set['world'].intersection(trends_set['col'])))

print(('='*10,'intersection of us and san-diego'))
print((trends_set['bogota'].intersection(trends_set['col'])))
# Out:
# ('==========', 'intersection of world and colombia')
# {'#FelizDomingo', '#F1xFOX'}
# ('==========', 'intersection of us and san-diego')
# {'#MargaritaOrtega', 'Quintero', 'Piedecuesta', '#RadioReal', 'Manuel', 'Cuadrado', 'Chará', '#ICFES', 'Ovelar', 'Juventus', '#BatallaDeLosGallos', '#FelizDomingo', 'Conor', '#FelizSabado', 'Once Caldas', 'Primera Emisión', '#PeleaDelSiglo', 'Chuck Norris', '#McGregor', '#F1xFOX', 'Egan Bernal', '#DíaDeLaCrispeta', 'Tigres', '#PeriodistasAsocajas', '#ForoCDTurismo', 'Demi Lovato', 'Venezuela y Brasil', 'Texas', '#PremiumXDIRECTV', 'Death Note'}

# %% [markdown]
# ## Example 5. Collecting search results

# %% [markdown]
# Set the variable `q` to a trending topic,
# or anything else for that matter. The example query below
# was a trending topic when this content was being developed
# and is used throughout the remainder of this chapter

# %%
q = '#ICFES' #q = topic 
number = 100

# See https://dev.twitter.com/docs/api/1.1/get/search/tweets

search_results = twitter_api.search.tweets(q=q, count=number)
statuses = search_results['statuses']

# %%
len(statuses)
print(statuses)
# Out:
# [{'created_at': 'Sun Aug 27 13:06:28 +0000 2017', 'id': 901793034064588800, 'id_str': '901793034064588800', 'text': 'RT @tweet_latino: Forma de responder el #ICFES : \n\nA) A la de Dios\nB) Bendíceme Señor\nC) Si no sé, es la C\nD) D de Diosito\n\nAhí les dejo el…', 'truncated': False, 'entities': {'hashtags': [{'text': 'ICFES', 'indices': [40, 46]}], 'symbols': [], 'user_mentions': [{'screen_name': 'tweet_latino', 'name': 'TweetLatino™', 'id': 746152640241893376, 'id_str': '746152640241893376', 'indices': [3, 16]}], 'urls': []}, 'metadata': {'iso_language_code': 'es', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 334971138, 'id_str': '334971138', 'name': 'Angy', 'screen_name': 'AngyPaola_1D', 'location': 'Valledupar', 'description': 'Universidad Nacional De Colombia😍', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 832, 'friends_count': 862, 'listed_count': 8, 'created_at': 'Wed Jul 13 23:24:44 +0000 2011', 'favourites_count': 749, 'utc_offset': -18000, 'time_zone': 'Bogota', 'geo_enabled': True, 'verified': False, 'statuses_count': 14911, 'lang': 'es', 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C1E5EB', 'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/818221607/4d1b6e334c8d50d430937eb46aa6f3b7.jpeg', 'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/818221607/4d1b6e334c8d50d430937eb46aa6f3b7.jpeg', 'profile_background_tile': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/712861501086937092/3sS50Gvs_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/712861501086937092/3sS50Gvs_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/334971138/1496121117', 'profile_link_color': 'B300AD', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Sat Aug 26 22:02:30 +0000 2017', 'id': 901565542556991489, 'id_str': '901565542556991489', 'text': 'Forma de responder el #ICFES : \n\nA) A la de Dios\nB) Bendíceme Señor\nC) Si no sé, es la C\nD) D de Diosito\n\nAhí les dejo el dato mis chinitos.', 'truncated': False, 'entities': {'hashtags': [{'text': 'ICFES', 'indices': [22, 28]}], 'symbols': [], 'user_mentions': [], 'urls': []}, 'metadata': {'iso_language_code': 'es', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 746152640241893376, 'id_str': '746152640241893376', 'name': 'TweetLatino™', 'screen_name': 'tweet_latino', 'location': 'Bogotá, D.C., Colombia', 'description': '//SIGAME  Y VERA QUE LE ALEGRO LOS DIAS //\n\nyo soy bonito pero si me vez de la perspectiva correcta: a 328 metros.', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 554, 'friends_count': 24, 'listed_count': 1, 'created_at': 'Fri Jun 24 01:27:07 +0000 2016', 'favourites_count': 32, 'utc_offset': -25200, 'time_zone': 'Pacific Time (US & Canada)', 'geo_enabled': False, 'verified': False, 'statuses_count': 597, 'lang': 'es', 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'p ...

# %% [markdown]
# Twitter often returns duplicate results, we can filter them out checking for duplicate texts:

# %%
all_text = []
filtered_statuses = []
for s in statuses:
    if not s["text"] in all_text:
        filtered_statuses.append(s)
        all_text.append(s["text"])
statuses = filtered_statuses

# %%
len(statuses)
# Out:
# 79

# %%
[s['text'] for s in search_results['statuses']]
# Out:
# ['RT @tweet_latino: Forma de responder el #ICFES : \n\nA) A la de Dios\nB) Bendíceme Señor\nC) Si no sé, es la C\nD) D de Diosito\n\nAhí les dejo el…',
#  'RT @Santiiago_W: Mañana en el #ICFES\n-Si Andrea va a la luna y la luz solar pega en la tierra, ¿Que tipo de hongo alucinógeno se comió Manu…',
#  '#ICFES Existos!',
#  'RT @Mey_boni: Cuando tuve q hacer la prueba dl #icfes no hacían actividads antiestres,cómo yoga.que les pasa a los jóvenes d ahora. No pues…',
#  'RT @guaritotapaazul: Mientras tanto a ésta hora en el #Icfes @ICFEScol https://t.co/4TxLUxeBNa',
#  'RT @duenax: Llegó el día de #Saber11 #Icfes.  Espero que hayan podido descansar. Enfrenten la prueba con calma que hay tiempo suficiente. @…',
#  'RT @duenax: Llegó el día de #Saber11 #Icfes.  Espero que hayan podido descansar. Enfrenten la prueba con calma que hay tiempo suficiente. @…',
#  'Les deseamos lo mejor a todos los estudiantes que presentan las pruebas #ICFES en todo el país el día de hoy :) https://t.co/eJ5StdcyoB',
#  'RT @guaritotapaazul: Mientras tanto a ésta hora en el #Icfes @ICFEScol https://t.co/4TxLUxeBNa',
#  'Como los molesto Oonce oonce🗣! Que les vaya súper en este #ICFES la sabiduría hoy este en sus mentes y la "rompan" con esos resultados. Los💜',
#  'RT @tweet_latino: Forma de responder el #ICFES : \n\nA) A la de Dios\nB) Bendíceme Señor\nC) Si no sé, es la C\nD) D de Diosito\n\nAhí les dejo el…',
#  'Mientras tanto a ésta hora en el #Icfes @ICFEScol https://t.co/4TxLUxeBNa',
#  'RT @BarraganFCB: Oh queridas pruebas SABER 11. Trátenme bien. #ICFES https://t.co/MfAMeWWDOX',
#  'En mañana soleada de domingo la @USTA_COLOMBIA recibe + de 2.500 bachilleres en las pruebas Saber 11, #ICFES, los m… https://t.co/MNTzGgk0Yv',
#  'RT @duenax: A todos los que vayan a presentar #Saber11 #icfes mañana, descansen para que lleguen energizados a la prueba.',
#  'RT @duenax: Llegó el día de #Saber11 #Icfes.  Espero que hayan podido descansar. Enfrenten la prueba con calma que hay tiempo suficiente. @…',
#  'Por qué hacen la #CaminataSolidaridad el mismo día que el #ICFES eso distrae a los chicos que presentan la prueba por esa zona (Me pasó)',
#  'Cuando presente el #ICFES fui conejillo de Indias con la prueba virtual. Fue bastante educativo presentarlo en un pc desde la uniandes.',
#  'Si @Pontifex_es hubiera llegado 10 dias antes, los presos academicos que esta presentando el #icfes estarian libres.',
#  'Encendamos una vela por las pobres criaturitas que están presentando el #ICFES hoy.',
#  '"Yo que voy a saber guevon"\n\n#icfes \n#PruebasSaber',
#  '#OrianaEnICFES #ICFES https://t.co/92PfIXCRtJ',
#  'Estoy a punto de presentar mis pruebas #ICFES 😣✌😥',
#  '@SectorMovilidad como son de miserables cerrar la 7a en el día de #ICFES',
#  'En pruebas #icfes no hay android o Apple q valga.',
#  'RT @razeofficial: A dormir, que mañana #ICFES',
#  'Ahora que pregunta rara saldra en el #ICFES xD',
#  'Consejos de preparación para la Prueba #ICFES Saber 11º \nhttps://t.co/36CRQmlgzE',
#  'RT @ValleduparCity: #ICFES #McGregor #MoneyFightxFOX Deseamos éxitos a todos los jóvenes que mañana presentan las pruebas Saber 11. ¡Ustede…',
#  'RT @duenax: Llegó el día de #Saber11 #Icfes.  Espero que hayan podido descansar. Enfrenten la prueba con calma que hay tiempo suficiente. @…',
#  'RT @andrexittooo: #ICFES https://t.co/blCOuZ4Qpb',
#  '#FelizDomingo\n#ICFES https://t.co/U5KDlyfeON',
#  '‟Egan Bernal‟\n‟Once Caldas‟\n#felizDomingo\n#ICFES\n#margaritaOrtega\nBocanegra\nCuadrado',
#  'Tendencias hoy 27/8 a esta hora en Colombia:\n#FelizDomingo\n#ICFES\nPrimera Emisión\n#MargaritaOrtega\n+en: https://t.co/Ljz5Rkjl2e',
#  'No olviden pedirle a Dios que los ilumine #ICFES https://t.co/EzfBO9h9XJ',
#  '#FelizDomingo\n#ICFES https://t.co/m7kjnFvaHr',
#  'A esta hora es tendencia en Twitter Colombia: #FelizDomingo\n#iCFES\n#margaritaOrtega',
#  '#FelizDomingo  me siento #mcgregor al presentar las #ICFES https://t.co/7NvTHz7Dfi',
#  'RT @BarraganFCB: Oh queridas pruebas SABER 11. Trátenme bien. #ICFES https://t.co/MfAMeWWDOX',
#  '#ICFES https://t.co/c6zeva1qRU',
#  '#ICFES https://t.co/blCOuZ4Qpb',
#  '1 pregunta pruebas #ICFES :\n\n🔃 si estudiastes\n❤️ Te tocara vender vive100',
#  'Buenos días. Con  entusiasmo estoy lista para presentar el examen del #ICFES. Como se podrán dar cuenta, hay cola.… https://t.co/om6ZBfvBJm',
#  'Ver a todos saludarse unos con otros y uno sin conocer a nadie. #ICFES',
#  '#ICFES EN FAMILIA https://t.co/NPcpr8qdbF',
#  'No faltan los que compraron ropa para ir a presentar el #icfes',
#  '#ICFES ACA TEMBLANDO CON UNA FILA DE MIERDA',
#  'Presentando el #ICFES EN FAMILIA https://t.co/XOrG5NSxxV',
#  'Muchachos recuerden salir para el #ICFES  con: \n- Lápiz #12\n- Borrador\n- sacapuntas\n- Escapulario',
#  'RT @duenax: Llegó el día de #Saber11 #Icfes.  Espero que hayan podido descansar. Enfrenten la prueba con calma que hay tiempo suficiente. @…',
#  '#ICFES #PeñalosaTransmileniófilo #PeñalosaTransmileniófilo #PeñalosaTransmileniófilo #PeñalosaTransmileniófilo #PeñalosaTransmileniófilo',
#  'RT @SebasLozadaD: Cuando vaya a salir de mi casa para ir al #ICFES: https://t.co/bljnhz4ZlL',
#  'RT @duenax: Llegó el día de #Saber11 #Icfes.  Espero que hayan podido descansar. Enfrenten la prueba con calma que hay tiempo suficiente. @…',
#  'Mk que miedooo #Icfes',
#  'RT @duenax: Llegó el día de #Saber11 #Icfes.  Espero que hayan podido descansar. Enfrenten la prueba con calma que hay tiempo suficiente. @…',
#  'Recuerden que para vender vive100 o Bonice no es necesario presentar las pruebas #ICFES',
#  'RT @SebasLozadaD: Cuando vaya a salir de mi casa para ir al #ICFES: https://t.co/bljnhz4ZlL',
#  'Hola @eldiariodedross hoy presento el #ICFES mandame tus bendiciones...',
#  'RT @tweet_latino: Forma de responder el #ICFES : \n\nA) A la de Dios\nB) Bendíceme Señor\nC) Si no sé, es la C\nD) D de Diosito\n\nAhí les dejo el…',
#  'RT @andresfsoca: -¿Y como te sientes para el #ICFES? 😝 https://t.co/8vV6FlNDo8',
#  'RT @Santiiago_W: *Los demás en el #ICFES*\n–Esto está fácil,me sirvió estudiar\n\n*Yo*\n–¿Será la B de bendito seas o la C de Cristo? Pongamos…',
#  'Vamos #ICFES 😎',
#  'Usted también hizo el #ICFES de dos días? Bienvenido a la vejez.',
#  'Alistarnos, esperan las #ICFES #Prom2017',
#  'Un saludo a los que les toca presentar el #icfes que le vaya bien y lleven chocolaticos o dulces y recen 4785349 padre nuestros.',
#  'RT @duenax: Llegó el día de #Saber11 #Icfes.  Espero que hayan podido descansar. Enfrenten la prueba con calma que hay tiempo suficiente. @…',
#  'RT @SebasLozadaD: Cuando vaya a salir de mi casa para ir al #ICFES: https://t.co/bljnhz4ZlL',
#  'Hay Morall ..Dios Dame Él Entendimiento 😂\n#ICFES 😍💪✊😌😏👏',
#  'Éxitos a todos los que presentan el #ICFES hoy !!  La próxima generación de los #Serpilopaga',
#  'Hay #DIOSITO Hoy es el #ICFES🤓jajajaa viajando desde #CHACHAGÜÍ a #PASTO jajaja q no llegue tarde 😂😂 #VIBRAPOSITIVA 🤓🌼',
#  'Mucha suerte a todos los que dan el #icfes hoy... especialmente a mi hermano tho',
#  '#ICFES QUE EMPIECEN LOS JUEGOS',
#  'Me fui solo hasta la mierda a presentar el #Icfes \n\nHoy me levantan para llevar a mi hijo y sus 4 amigos. #Zanganos \n\n#ConLosBuenosDias',
#  'Quién está despierto ya para ir a sufrir todo el día? #ICFES',
#  'RT @andresfsoca: -¿Y como te sientes para el #ICFES? 😝 https://t.co/8vV6FlNDo8',
#  'RT @duenax: Llegó el día de #Saber11 #Icfes.  Espero que hayan podido descansar. Enfrenten la prueba con calma que hay tiempo suficiente. @…',
#  '#ICFES pensé que nunca llegaríamos hasta acá',
#  'Llegó el día de #Saber11 #Icfes.  Espero que hayan podido descansar. Enfrenten la prueba con calma que hay tiempo suficiente. @ICFEScol',
#  'Relajarse y disfrutar❣️ #ICFES',
#  'Voy con toda ⚡\n#ICFES',
#  'JUEMADRE PERDÍ  #ICFES \nNervios. Miedo. Inseguridad. D de Diosito. 😂😢\nA de Amén\nB de Bendición\nC de cristo\nD. Diosito\nJuemadre perdí',
#  'Vamos con todaa. 💪🖎 #ICFES',
#  'Para los que presentan el #Icfes hoy, les deseo los mejores éxitos, que les vaya excelente y que lean muy bien, no se duerman 😉👊',
#  'RT @SebasLozadaD: Cuando vaya a salir de mi casa para ir al #ICFES: https://t.co/bljnhz4ZlL',
#  '¡Por fín llegó el día! #ICFES',
#  "Ya es hora del #ICFES  pero tengo Esperanza :'v",
#  'RT @tweet_latino: Forma de responder el #ICFES : \n\nA) A la de Dios\nB) Bendíceme Señor\nC) Si no sé, es la C\nD) D de Diosito\n\nAhí les dejo el…',
#  'Prueba de Estado ICFES... ¡¡Suerte y fuerza para todos!! #ICFES',
#  'Gente vamos por el 420 #ICFES',
#  'Bueeeeeenos diaaaas!!! Con ánimo y determinación para el #ICFES ❤️💪. Bendiciones!',
#  'Y recuerden que el ICFES es con el uniforme de diario. #ICFES',
#  'Hoy es el día en que muchos jóvenes se ven acompañados de sus padres rumbo a presentar el #ICFES ... Mucha sabiduria para todos. 🤓📑',
#  '@OlgaLuciaVives Cómo cuando Olga decide hacer live, y tú no lo podrás ver porque estaras en las #ICFES 😥',
#  'Llegó El Gran Día #ICFES Te pido señor que me des mucha sabiduría y que seas tú tomando el control en todo: me siento bendecida',
#  'RT @SebasLozadaD: Cuando vaya a salir de mi casa para ir al #ICFES: https://t.co/bljnhz4ZlL',
#  'RT @ValleduparCity: #ICFES #McGregor #MoneyFightxFOX Deseamos éxitos a todos los jóvenes que mañana presentan las pruebas Saber 11. ¡Ustede…',
#  'RT @duenax: A todos los que vayan a presentar #Saber11 #icfes mañana, descansen para que lleguen energizados a la prueba.',
#  'Desde ya se empiezan a levantar los que van a presentar el #ICFES, tanta fiebre para saber que van a terminar vendiendo vive100 y Avon.',
#  'RT @Real_ShaziaN: Mañana es el día, no puedo creerlo. Vamos por esa beca, @louizfk #ICFES',
#  'RT @Real_ShaziaN: Mañana es el día, no puedo creerlo. Vamos por esa beca, @louizfk #ICFES']

# %%
# Show one sample search result by slicing the list...
print(json.dumps(statuses[0], indent=1))
# Out:
# {
#  "created_at": "Sun Aug 27 13:06:28 +0000 2017",
#  "id": 901793034064588800,
#  "id_str": "901793034064588800",
#  "text": "RT @tweet_latino: Forma de responder el #ICFES : \n\nA) A la de Dios\nB) Bend\u00edceme Se\u00f1or\nC) Si no s\u00e9, es la C\nD) D de Diosito\n\nAh\u00ed les dejo el\u2026",
#  "truncated": false,
#  "entities": {
#   "hashtags": [
#    {
#     "text": "ICFES",
#     "indices": [
#      40,
#      46
#     ]
#    }
#   ],
#   "symbols": [],
#   "user_mentions": [
#    {
#     "screen_name": "tweet_latino",
#     "name": "TweetLatino\u2122",
#     "id": 746152640241893376,
#     "id_str": "746152640241893376",
#     "indices": [
#      3,
#      16
#     ]
#    }
#   ],
#   "urls": []
#  },
#  "metadata": {
#   "iso_language_code": "es",
#   "result_type": "recent"
#  },
#  "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#  "in_reply_to_status_id": null,
#  "in_reply_to_status_id_str": null,
#  "in_reply_to_user_id": null,
#  "in_reply_to_user_id_str": null,
#  "in_reply_to_screen_name": null,
#  "user": {
#   "id": 334971138,
#   "id_str": "334971138",
#   "name": "Angy",
#   "screen_name": "AngyPaola_1D",
#   "location": "Valledupar",
#   "description": "Universidad Nacional De Colombia\ud83d\ude0d",
#   "url": null,
#   "entities": {
#    "description": {
#     "urls": []
#    }
#   },
#   "protected": false,
#   "followers_count": 832,
#   "friends_count": 862,
#   "listed_count": 8,
#   "created_at": "Wed Jul 13 23:24:44 +0000 2011",
#   "favourites_count": 749,
#   "utc_offset": -18000,
#   "time_zone": "Bogota",
#   "geo_enabled": true,
#   "verified": false,
#   "statuses_count": 14911,
#   "lang": "es",
#   "contributors_enabled": false,
#   "is_translator": false,
#   "is_translation_enabled": false,
#   "profile_background_color": "C1E5EB",
#   "profile_background_image_url": "http://pbs.twimg.com/profile_background_images/818221607/4d1b6e334c8d50d430937eb46aa6f3b7.jpeg",
#   "profile_background_image_url_https": "https://pbs.twimg.com/profile_background_images/818221607/4d1b6e334c8d50d430937eb46aa6f3b7.jpeg",
#   "profile_background_tile": true,
#   "profile_image_url": "http://pbs.twimg.com/profile_images/712861501086937092/3sS50Gvs_normal.jpg",
#   "profile_image_url_https": "https://pbs.twimg.com/profile_images/712861501086937092/3sS50Gvs_normal.jpg",
#   "profile_banner_url": "https://pbs.twimg.com/profile_banners/334971138/1496121117",
#   "profile_link_color": "B300AD",
#   "profile_sidebar_border_color": "FFFFFF",
#   "profile_sidebar_fill_color": "DDEEF6",
#   "profile_text_color": "333333",
#   "profile_use_background_image": true,
#   "has_extended_profile": true,
#   "default_profile": false,
#   "default_profile_image": false,
#   "following": false,
#   "follow_request_sent": false,
#   "notifications": false,
#   "translator_type": "none"
#  },
#  "geo": null,
#  "coordinates": null,
#  "place": null,
#  "contributors": null,
#  "retweeted_status": {
#   "created_at": "Sat Aug 26 22:02:30 +0000 2017",
#   "id": 901565542556991489,
#   "id_str": "901565542556991489",
#   "text": "Forma de responder el #ICFES : \n\nA) A la de Dios\nB) Bend\u00edceme Se\u00f1or\nC) Si no s\u00e9, es la C\nD) D de Diosito\n\nAh\u00ed les dejo el dato mis chinitos.",
#   "truncated": false,
#   "entities": {
#    "hashtags": [
#     {
#      "text": "ICFES",
#      "indices": [
#       22,
#       28
#      ]
#     }
#    ],
#    "symbols": [],
#    "user_mentions": [],
#    "urls": []
#   },
#   "metadata": {
#    "iso_language_code": "es",
#    "result_type": "recent"
#   },
#   "source": "<a href=\"http://twitter.com\" rel=\"nofollow\">Twitter Web Client</a>",
#   "in_reply_to_status_id": null,
#   "in_reply_to_status_id_str": null,
#   "in_reply_to_user_id": null,
#   "in_reply_to_user_id_str": null,
#   "in_reply_to_screen_name": null,
#   "user": {
#    "id": 746152640241893376,
#    "id_str": "746152640241893376",
#    "name": "TweetLatino\u2122",
#    "screen_name": "tweet_latino",
#    "location": "Bogot\u00e1, D.C., Colombia",
#    "description": "//SIGAME  Y VERA QUE LE ALEGRO LOS DIAS //\n\nyo soy bonito pero si me vez de la perspectiva correcta: a 328 metros.",
#    "url": null,
#    "entities": {
#     "description": {
#      "urls": []
#     }
#    },
#    "protected": false,
#    "followers_count": 554,
#    "friends_count": 24,
#    "listed_count": 1,
#    "created_at": "Fri Jun 24 01:27:07 +0000 2016",
#    "favourites_count": 32,
#    "utc_offset": -25200,
#    "time_zone": "Pacific Time (US & Canada)",
#    "geo_enabled": false,
#    "verified": false,
#    "statuses_count": 597,
#    "lang": "es",
#    "contributors_enabled": false,
#    "is_translator": false,
#    "is_translation_enabled": false,
#    "profile_background_color": "F5F8FA",
#    "profile_background_image_url": null,
#    "profile_background_image_url_https": null,
#    "profile_background_tile": false,
#    "profile_image_url": "http://pbs.twimg.com/profile_images/746156943362920448/jJzVGUNG_normal.jpg",
#    "profile_image_url_https": "https://pbs.twimg.com/profile_images/746156943362920448/jJzVGUNG_normal.jpg",
#    "profile_banner_url": "https://pbs.twimg.com/profile_banners/746152640241893376/1483921287",
#    "profile_link_color": "1DA1F2",
#    "profile_sidebar_border_color": "C0DEED",
#    "profile_sidebar_fill_color": "DDEEF6",
#    "profile_text_color": "333333",
#    "profile_use_background_image": true,
#    "has_extended_profile": true,
#    "default_profile": true,
#    "default_profile_image": false,
#    "following": false,
#    "follow_request_sent": false,
#    "notifications": false,
#    "translator_type": "none"
#   },
#   "geo": null,
#   "coordinates": null,
#   "place": null,
#   "contributors": null,
#   "is_quote_status": false,
#   "retweet_count": 18,
#   "favorite_count": 55,
#   "favorited": false,
#   "retweeted": false,
#   "lang": "es"
#  },
#  "is_quote_status": false,
#  "retweet_count": 18,
#  "favorite_count": 0,
#  "favorited": false,
#  "retweeted": false,
#  "lang": "es"
# }

# %%
# The result of the list comprehension is a list with only one element that
# can be accessed by its index and set to the variable t
t = statuses[10]
#[ status for status in statuses 
#          if status['id'] == 316948241264549888 ][0]

# Explore the variable t to get familiarized with the data structure...

print(t['retweet_count'])
print(t['retweeted'])
print(t['coordinates'])
# Out:
# 0
# False
# None

# %% [markdown]
# ## Example 6. Extracting text, screen names, and hashtags from tweets

# %%
status_texts = [ status['text'] 
                 for status in statuses ]

screen_names = [ user_mention['screen_name'] 
                 for status in statuses
                     for user_mention in status['entities']['user_mentions'] ]

hashtags = [ hashtag['text'] 
             for status in statuses
                 for hashtag in status['entities']['hashtags'] ]

# Compute a collection of all words from all tweets
words = [ w 
          for t in status_texts 
              for w in t.split() ]

# %%
# Explore the first 5 items for each...

print(json.dumps(status_texts[0:5], indent=1))
print(json.dumps(screen_names[0:5], indent=1)) 
print(json.dumps(hashtags[0:5], indent=1))
print(json.dumps(words[0:5], indent=1))
# Out:
# [
#  "RT @tweet_latino: Forma de responder el #ICFES : \n\nA) A la de Dios\nB) Bend\u00edceme Se\u00f1or\nC) Si no s\u00e9, es la C\nD) D de Diosito\n\nAh\u00ed les dejo el\u2026",
#  "RT @Santiiago_W: Ma\u00f1ana en el #ICFES\n-Si Andrea va a la luna y la luz solar pega en la tierra, \u00bfQue tipo de hongo alucin\u00f3geno se comi\u00f3 Manu\u2026",
#  "#ICFES Existos!",
#  "RT @Mey_boni: Cuando tuve q hacer la prueba dl #icfes no hac\u00edan actividads antiestres,c\u00f3mo yoga.que les pasa a los j\u00f3venes d ahora. No pues\u2026",
#  "RT @guaritotapaazul: Mientras tanto a \u00e9sta hora en el #Icfes @ICFEScol https://t.co/4TxLUxeBNa"
# ]
# [
#  "tweet_latino",
#  "Santiiago_W",
#  "Mey_boni",
#  "guaritotapaazul",
#  "ICFEScol"
# ]
# [
#  "ICFES",
#  "ICFES",
#  "ICFES",
#  "icfes",
#  "Icfes"
# ]
# [
#  "RT",
#  "@tweet_latino:",
#  "Forma",
#  "de",
#  "responder"
# ]

# %% [markdown]
# ## Example 7. Creating a basic frequency distribution from the words in tweets

# %%
from collections import Counter

for item in [words, screen_names, hashtags]:
    c = Counter(item)
    print(c.most_common()[:10]) # top 10
    print()
# Out:
# [('#ICFES', 56), ('el', 40), ('que', 33), ('a', 30), ('de', 26), ('la', 22), ('en', 17), ('los', 17), ('RT', 14), ('para', 14)]
#
# [('ICFEScol', 3), ('Santiiago_W', 2), ('duenax', 2), ('tweet_latino', 1), ('Mey_boni', 1), ('guaritotapaazul', 1), ('BarraganFCB', 1), ('USTA_COLOMBIA', 1), ('Pontifex_es', 1), ('SectorMovilidad', 1)]
#
# [('ICFES', 63), ('icfes', 8), ('Icfes', 7), ('FelizDomingo', 5), ('PeñalosaTransmileniófilo', 5), ('Saber11', 3), ('margaritaOrtega', 2), ('CaminataSolidaridad', 1), ('PruebasSaber', 1), ('OrianaEnICFES', 1)]

# %% [markdown]
# ## Example 8. Create a prettyprint function to display tuples in a nice tabular format

# %%
def prettyprint_counts(label, list_of_tuples):
    print("\n{:^20} | {:^6}".format(label, "Count"))
    print("*"*40)
    for k,v in list_of_tuples:
        print("{:20} | {:>6}".format(k,v))

# %%
for label, data in (('Word', words), 
                    ('Screen Name', screen_names), 
                    ('Hashtag', hashtags)):
    
    c = Counter(data)
    prettyprint_counts(label, c.most_common()[:10])
# Out:
#         Word         | Count
# ****************************************
# #ICFES               |     56
# el                   |     40
# que                  |     33
# a                    |     30
# de                   |     26
# la                   |     22
# en                   |     17
# los                  |     17
# RT                   |     14
# para                 |     14
#
#     Screen Name      | Count
# ****************************************
# ICFEScol             |      3
# Santiiago_W          |      2
# duenax               |      2
# tweet_latino         |      1
# Mey_boni             |      1
# guaritotapaazul      |      1
# BarraganFCB          |      1
# USTA_COLOMBIA        |      1
# Pontifex_es          |      1
# SectorMovilidad      |      1
#
#       Hashtag        | Count
# ****************************************
# ICFES                |     63
# icfes                |      8
# Icfes                |      7
# FelizDomingo         |      5
# PeñalosaTransmileniófilo |      5
# Saber11              |      3
# margaritaOrtega      |      2
# CaminataSolidaridad  |      1
# PruebasSaber         |      1
# OrianaEnICFES        |      1

# %% [markdown]
# ## Example 9. Finding the most popular retweets

# %%
retweets = [
            # Store out a tuple of these three values ...
            (status['retweet_count'], 
             status['retweeted_status']['user']['screen_name'],
             status['text'].replace("\n","\\")) 
            
            # ... for each status ...
            for status in statuses 
                # ... so long as the status meets this condition.
                if 'retweeted_status' in status
           ]

# %% [markdown]
# We can build another `prettyprint` function to print entire tweets with their retweet count.
#
# We also want to split the text of the tweet in up to 3 lines, if needed.

# %%
row_template = "{:^7} | {:^15} | {:50}"
def prettyprint_tweets(list_of_tuples):
    print()
    print(row_template.format("Count", "Screen Name", "Text"))
    print("*"*80)
    for count, screen_name, text in list_of_tuples:
        print(row_template.format(count, screen_name, text[:50]))
        if len(text) > 50:
            print(row_template.format("", "", text[50:100]))
            if len(text) > 100:
                print(row_template.format("", "", text[100:]))

# %%
# Slice off the first 5 from the sorted results and display each item in the tuple

prettyprint_tweets(sorted(retweets, reverse=True)[:10])
# Out:
#  Count  |   Screen Name   | Text
# ********************************************************************************
#   66    |   andresfsoca   | RT @andresfsoca: -¿Y como te sientes para el #ICFE
#         |                 | S? 😝 https://t.co/8vV6FlNDo8
#   23    |  razeofficial   | RT @razeofficial: A dormir, que mañana #ICFES
#   18    |  tweet_latino   | RT @tweet_latino: Forma de responder el #ICFES : \
#         |                 | \A) A la de Dios\B) Bendíceme Señor\C) Si no sé, e
#         |                 | s la C\D) D de Diosito\\Ahí les dejo el…
#   15    |   BarraganFCB   | RT @BarraganFCB: Oh queridas pruebas SABER 11. Trá
#         |                 | tenme bien. #ICFES https://t.co/MfAMeWWDOX
#   14    |   Santiiago_W   | RT @Santiiago_W: *Los demás en el #ICFES*\–Esto es
#         |                 | tá fácil,me sirvió estudiar\\*Yo*\–¿Será la B de b
#         |                 | endito seas o la C de Cristo? Pongamos…
#    9    |     duenax      | RT @duenax: Llegó el día de #Saber11 #Icfes.  Espe
#         |                 | ro que hayan podido descansar. Enfrenten la prueba
#         |                 |  con calma que hay tiempo suficiente. @…
#    8    |     duenax      | RT @duenax: A todos los que vayan a presentar #Sab
#         |                 | er11 #icfes mañana, descansen para que lleguen ene
#         |                 | rgizados a la prueba.
#    7    |  SebasLozadaD   | RT @SebasLozadaD: Cuando vaya a salir de mi casa p
#         |                 | ara ir al #ICFES: https://t.co/bljnhz4ZlL
#    6    | ValleduparCity  | RT @ValleduparCity: #ICFES #McGregor #MoneyFightxF
#         |                 | OX Deseamos éxitos a todos los jóvenes que mañana
#         |                 | presentan las pruebas Saber 11. ¡Ustede…
#    5    |   Santiiago_W   | RT @Santiiago_W: Mañana en el #ICFES\-Si Andrea va
#         |                 |  a la luna y la luz solar pega en la tierra, ¿Que
#         |                 | tipo de hongo alucinógeno se comió Manu…
